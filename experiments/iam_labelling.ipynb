# %%
# auto reload
# %load_ext autoreload
# %autoreload 2

import torch
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import os
import scipy
import random
from glob import glob
from skimage import transform
from tqdm import tqdm

try:
    print(os.getcwd())
    os.chdir("../../rug-hr/")
    print(os.getcwd())
except:
    pass
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from modules.scripturize import sample_manuscript_from_corpus
from modules.scripturize.utils.font import load_font
from modules.scripturize.text_writer import generate_image_from_token, time2token, \
    label_chars_in_token, token2image

token = "martino's test"
font_size = 128
font_path = "./assets/fonts_cursive/AdineKirnberg-Script.ttf"

image = token2image(token, font_size, font_path=font_path)
labelled_image = label_chars_in_token(token, font_size, font_path=font_path)

# plot side to side
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(image, cmap='gray')
ax2.imshow(generate_image_from_token(token, font_size, font_path=font_path), cmap='CMRmap')
plt.show()
